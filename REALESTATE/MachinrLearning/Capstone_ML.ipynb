# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df1=pd.read_excel("Table_1.xlsx")

# %%
df1
# Out:
#       S.NO  BHK_TYPE PROP_TYPE  BEDS  BATHROOM  BALCONY       CITY STATE_CODE  \
# 0        1         1    Budget     1         1        1    Chennai         TN
# 1        2         1    Budget     1         1        1    Chennai         TN
# 2        3         1    Budget     1         1        1    Chennai         TN
# 3        4         1    Budget     1         1        1    Chennai         TN
# 4        5         1    Budget     1         1        1    Chennai         TN
# ...    ...       ...       ...   ...       ...      ...        ...        ...
# 3008  3009         5     Condo     5         5        5  Losangels         CA
# 3009  3010         5     Condo     5         5        5  Losangels         CA
# 3010  3011         5     Condo     5         5        5  Losangels         CA
# 3011  3012         5     Condo     5         5        5  Losangels         CA
# 3012  3013         5     Condo     5         5        5  Losangels         CA
#
#      COUNTRY
# 0      INDIA
# ...

# %%
df2=pd.read_excel("Table_2.xlsx")

# %%
df2
# Out:
#       S.NO  CARPET  FLOOR TRANSACTION_TYPE  BUILT_YEAR  PRICE_PER_SFT
# 0        1     400      1             CASH        2000           3000
# 1        2     400      1             CASH        2000           3000
# 2        3     400      1             CASH        2000           3000
# 3        4     400      1             CASH        2000           3000
# 4        5     400      1             CASH        2000           3000
# ...    ...     ...    ...              ...         ...            ...
# 3008  3009    1100      5             LOAN        2020           7000
# 3009  3010    1100      5             LOAN        2020           7000
# 3010  3011    1100      5             LOAN        2020           7000
# 3011  3012    1100      5             LOAN        2020           7000
# 3012  3013    1100      5             LOAN        2020           7000
#
# [3013 rows x 6 columns]

# %%
df3=pd.read_excel("Table_3.xlsx")

# %%
df3
# Out:
#       S.NO FURNITURE_STATUS FACING CAR_PARKING OWNERSHIP_TYPE  BOOKING_AMOUNT  \
# 0        1               NO   EAST          NO           SOLE           30000
# 1        2               NO   EAST          NO           SOLE           30000
# 2        3               NO   EAST          NO           SOLE           30000
# 3        4               NO   EAST          NO           SOLE           30000
# 4        5               NO   EAST          NO           SOLE           30000
# ...    ...              ...    ...         ...            ...             ...
# 3008  3009              YES  SOUTH         YES          JOINT          250000
# 3009  3010              YES  SOUTH         YES          JOINT          250000
# 3010  3011              YES  SOUTH         YES          JOINT          250000
# 3011  3012              YES  SOUTH         YES          JOINT          250000
# 3012  3013              YES  SOUTH         YES          JOINT          250000
#
#       TOTAL_AMOUNT
# ...

# %%
temp=df1.merge(df2,how='right')
temp
# Out:
#       S.NO  BHK_TYPE PROP_TYPE  BEDS  BATHROOM  BALCONY       CITY STATE_CODE  \
# 0        1         1    Budget     1         1        1    Chennai         TN
# 1        2         1    Budget     1         1        1    Chennai         TN
# 2        3         1    Budget     1         1        1    Chennai         TN
# 3        4         1    Budget     1         1        1    Chennai         TN
# 4        5         1    Budget     1         1        1    Chennai         TN
# ...    ...       ...       ...   ...       ...      ...        ...        ...
# 3008  3009         5     Condo     5         5        5  Losangels         CA
# 3009  3010         5     Condo     5         5        5  Losangels         CA
# 3010  3011         5     Condo     5         5        5  Losangels         CA
# 3011  3012         5     Condo     5         5        5  Losangels         CA
# 3012  3013         5     Condo     5         5        5  Losangels         CA
#
# ...

# %%
df=temp.merge(df3,how='right')
df
# Out:
#       S.NO  BHK_TYPE PROP_TYPE  BEDS  BATHROOM  BALCONY       CITY STATE_CODE  \
# 0        1         1    Budget     1         1        1    Chennai         TN
# 1        2         1    Budget     1         1        1    Chennai         TN
# 2        3         1    Budget     1         1        1    Chennai         TN
# 3        4         1    Budget     1         1        1    Chennai         TN
# 4        5         1    Budget     1         1        1    Chennai         TN
# ...    ...       ...       ...   ...       ...      ...        ...        ...
# 3008  3009         5     Condo     5         5        5  Losangels         CA
# 3009  3010         5     Condo     5         5        5  Losangels         CA
# 3010  3011         5     Condo     5         5        5  Losangels         CA
# 3011  3012         5     Condo     5         5        5  Losangels         CA
# 3012  3013         5     Condo     5         5        5  Losangels         CA
#
# ...

# %%
df.columns
# Out:
# Index(['S.NO', 'BHK_TYPE', 'PROP_TYPE', 'BEDS', 'BATHROOM', 'BALCONY', 'CITY',
#        'STATE_CODE', 'COUNTRY', 'CARPET', 'FLOOR', 'TRANSACTION_TYPE',
#        'BUILT_YEAR', 'PRICE_PER_SFT', 'FURNITURE_STATUS', 'FACING',
#        'CAR_PARKING', 'OWNERSHIP_TYPE', 'BOOKING_AMOUNT', 'TOTAL_AMOUNT'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3013 entries, 0 to 3012
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   S.NO              3013 non-null   int64
#  1   BHK_TYPE          3013 non-null   int64
#  2   PROP_TYPE         3013 non-null   object
#  3   BEDS              3013 non-null   int64
#  4   BATHROOM          3013 non-null   int64
#  5   BALCONY           3013 non-null   int64
#  6   CITY              3013 non-null   object
#  7   STATE_CODE        2519 non-null   object
#  8   COUNTRY           3013 non-null   object
#  9   CARPET            3013 non-null   int64
#  10  FLOOR             3013 non-null   int64
#  11  TRANSACTION_TYPE  3013 non-null   object
#  12  BUILT_YEAR        3013 non-null   int64
#  13  PRICE_PER_SFT     3013 non-null   int64
#  14  FURNITURE_STATUS  3013 non-null   object
#  15  FACING            3013 non-null   object
# ...

# %%
df.describe().T
# Out:
#                  count          mean           std        min        25%  \
# S.NO            3013.0  1.507000e+03  8.699225e+02        1.0      754.0
# BHK_TYPE        3013.0  3.001328e+00  1.316964e+00        1.0        2.0
# BEDS            3013.0  3.003319e+00  1.369363e+00        1.0        2.0
# BATHROOM        3013.0  2.949884e+00  1.349270e+00        1.0        2.0
# BALCONY         3013.0  2.952207e+00  1.346275e+00        1.0        2.0
# CARPET          3013.0  7.049270e+02  1.414761e+02      400.0      640.0
# FLOOR           3013.0  3.184534e+00  1.230613e+00        1.0        2.0
# BUILT_YEAR      3013.0  2.008869e+03  6.827635e+00     2000.0     2004.0
# PRICE_PER_SFT   3013.0  4.123565e+03  1.218440e+03     3000.0     3100.0
# BOOKING_AMOUNT  3013.0  8.081646e+04  4.194551e+04    30000.0    60000.0
# TOTAL_AMOUNT    3013.0  1.348410e+07  1.328712e+07  2000000.0  3000000.0
#
#                       50%         75%         max
# ...

# %%
df.nunique()
# Out:
# S.NO                3013
# BHK_TYPE               5
# PROP_TYPE              2
# BEDS                   5
# BATHROOM               5
# BALCONY                5
# CITY                   6
# STATE_CODE             6
# COUNTRY                2
# CARPET                26
# FLOOR                  5
# TRANSACTION_TYPE       3
# BUILT_YEAR            13
# PRICE_PER_SFT         14
# FURNITURE_STATUS       2
# FACING                 4
# CAR_PARKING            2
# OWNERSHIP_TYPE         2
# BOOKING_AMOUNT        11
# TOTAL_AMOUNT          17
# dtype: int64

# %%
print(df['BEDS'].value_counts())
sns.countplot(x='BEDS', data=df)
plt.show()
# Out:
# BEDS
# 4    882
# 1    654
# 3    620
# 5    431
# 2    426
# Name: count, dtype: int64

# %%
print(df['BATHROOM'].value_counts())
sns.countplot(x='BATHROOM', data=df)
plt.show()
# Out:
# BATHROOM
# 4    902
# 1    661
# 3    612
# 2    469
# 5    369
# Name: count, dtype: int64

# %%
print(df['CITY'].value_counts())
sns.countplot(x='CITY', data=df)
plt.show()
# Out:
# CITY
# Losangels    849
# Newyork      494
# Banglore     480
# Mumbai       446
# Hyderabad    412
# Chennai      332
# Name: count, dtype: int64

# %%
print(df['OWNERSHIP_TYPE'].value_counts())
sns.countplot(x='OWNERSHIP_TYPE', data=df)
plt.show()
# Out:
# OWNERSHIP_TYPE
# JOINT    2080
# SOLE      933
# Name: count, dtype: int64

# %%
print(df['FACING'].value_counts())
sns.countplot(x='FACING', data=df)
plt.show()
# Out:
# FACING
# WEST     1037
# NORTH     867
# SOUTH     728
# EAST      381
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.describe(),linewidths = 0.1,fmt='0.1f',annot = True)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3013 entries, 0 to 3012
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   S.NO              3013 non-null   int64
#  1   BHK_TYPE          3013 non-null   int64
#  2   PROP_TYPE         3013 non-null   object
#  3   BEDS              3013 non-null   int64
#  4   BATHROOM          3013 non-null   int64
#  5   BALCONY           3013 non-null   int64
#  6   CITY              3013 non-null   object
#  7   STATE_CODE        2519 non-null   object
#  8   COUNTRY           3013 non-null   object
#  9   CARPET            3013 non-null   int64
#  10  FLOOR             3013 non-null   int64
#  11  TRANSACTION_TYPE  3013 non-null   object
#  12  BUILT_YEAR        3013 non-null   int64
#  13  PRICE_PER_SFT     3013 non-null   int64
#  14  FURNITURE_STATUS  3013 non-null   object
#  15  FACING            3013 non-null   object
# ...

# %%
Numerical=['S.NO','BHK_TYPE','BEDS','BATHROOM','BALCONY','CARPET','FLOOR','BUILT_YEAR','PRICE_PER_SFT','BOOKING_AMOUNT','TOTAL_AMOUNT']
Catogirical=['PROP_TYPE','CITY','STATE_CODE','TRANSACTION_TYPE','COUNTRY','FURNITURE_STATUS','FACING','CAR_PARKING','OWNERSHIP_TYPE']

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for col in Numerical:
    if plotnumber <=12:
       ax=plt.subplot(4,3,plotnumber)
       sns.distplot(df[col])
       plt.xlabel(col,fontsize=12)
       plt.yticks()
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for col in Numerical:
    if plotnumber <=16:
       ax=plt.subplot(4,3,plotnumber)
       sns.stripplot(df[col])
       plt.xlabel(col,fontsize=12)
       plt.yticks()
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for col in Numerical:
    if plotnumber <=16:
       ax=plt.subplot(4,4,plotnumber)
       sns.boxplot(df[col])
       plt.xlabel(col,fontsize=12)
       plt.yticks()
    plotnumber+=1
plt.tight_layout()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
for i in Catogirical:
    df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#       S.NO  BHK_TYPE  PROP_TYPE  BEDS  BATHROOM  BALCONY  CITY  STATE_CODE  \
# 0        1         1          0     1         1        1     1           4
# 1        2         1          0     1         1        1     1           4
# 2        3         1          0     1         1        1     1           4
# 3        4         1          0     1         1        1     1           4
# 4        5         1          0     1         1        1     1           4
# ...    ...       ...        ...   ...       ...      ...   ...         ...
# 3008  3009         5          1     5         5        5     3           0
# 3009  3010         5          1     5         5        5     3           0
# 3010  3011         5          1     5         5        5     3           0
# 3011  3012         5          1     5         5        5     3           0
# 3012  3013         5          1     5         5        5     3           0
#
# ...

# %%
sns.pairplot(df, hue="PRICE_PER_SFT")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=df.corr(),annot=True,fmt='0.3f',linecolor="black",linewidths=0.1)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.distplot(x=df["TOTAL_AMOUNT"], hist=False, color="y", kde_kws={"shade": True})
plt.show()

# %%
X = df.drop(['TOTAL_AMOUNT','S.NO'], axis=1)
Y = df['TOTAL_AMOUNT']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X=pd.DataFrame(scaler.fit_transform(X),columns=X.columns)
X
# Out:
#       BHK_TYPE  PROP_TYPE      BEDS  BATHROOM   BALCONY      CITY  STATE_CODE  \
# 0    -1.519905  -1.019777 -1.463200 -1.445380 -1.450321 -1.001180    0.556222
# 1    -1.519905  -1.019777 -1.463200 -1.445380 -1.450321 -1.001180    0.556222
# 2    -1.519905  -1.019777 -1.463200 -1.445380 -1.450321 -1.001180    0.556222
# 3    -1.519905  -1.019777 -1.463200 -1.445380 -1.450321 -1.001180    0.556222
# 4    -1.519905  -1.019777 -1.463200 -1.445380 -1.450321 -1.001180    0.556222
# ...        ...        ...       ...       ...       ...       ...         ...
# 3008  1.517888   0.980606  1.458351  1.519679  1.521333  0.219109   -1.211601
# 3009  1.517888   0.980606  1.458351  1.519679  1.521333  0.219109   -1.211601
# 3010  1.517888   0.980606  1.458351  1.519679  1.521333  0.219109   -1.211601
# 3011  1.517888   0.980606  1.458351  1.519679  1.521333  0.219109   -1.211601
# 3012  1.517888   0.980606  1.458351  1.519679  1.521333  0.219109   -1.211601
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression

# %%
maxAccu=0
maxRS=0

for i in range(1, 1000):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=i)
    lr=LinearRegression()
    lr.fit(X_train, Y_train)
    pred = lr.predict(X_test)
    r2 = r2_score(Y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.9540763882143034 on Random State 151

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=151)

# %%
from sklearn.model_selection import cross_val_score

# %%
def reg(model, X, Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=151)
    model.fit(X_train, Y_train)
    pred = model.predict(X_test)
    rmse = mean_squared_error(Y_test, pred,squared=False)
    print("RMSE Score is:", rmse)
    r2 = r2_score(Y_test, pred)*100
    print("R2 Score is:", r2)
    cv_score = (cross_val_score(model, X, Y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    result = r2 - cv_score
    print("R2 Score - Cross Validation Score is", result)

# %%
model=LinearRegression()
reg(model,X,Y)
# Out:
# RMSE Score is: 2914460.1476517017
# R2 Score is: 95.40763882143034
# Cross Validation Score: -19599.85173275332
# R2 Score - Cross Validation Score is 19695.25937157475

# %%
from sklearn.linear_model import Ridge

# %%
model=Ridge()
reg(model,X,Y)
# Out:
# RMSE Score is: 2916145.760127809
# R2 Score is: 95.40232519253335
# Cross Validation Score: -19487.61146638844
# R2 Score - Cross Validation Score is 19583.013791580972

# %%
from sklearn.linear_model import Lasso

# %%
model=Lasso()
reg(model,X,Y)
# Out:
# RMSE Score is: 2914461.2784444736
# R2 Score is: 95.40763525781337
# Cross Validation Score: -19599.463647627876
# R2 Score - Cross Validation Score is 19694.871282885688

# %%
from sklearn.svm import SVR

# %%
model=SVR(C=1.0, epsilon=0.2, kernel='poly')
reg(model, X, Y)
# Out:
# RMSE Score is: 16858522.4811557
# R2 Score is: -53.65928694277058
# Cross Validation Score: -82583.79509467228
# R2 Score - Cross Validation Score is 82530.13580772952

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %%
model=DecisionTreeRegressor()
reg(model, X, Y)
# Out:
# RMSE Score is: 1210287.942949801
# R2 Score is: 99.20805101175947
# Cross Validation Score: -418.0535711763786
# R2 Score - Cross Validation Score is 517.2616221881381

# %%
model=RandomForestRegressor(max_depth=2)
reg(model, X, Y)
# Out:
# RMSE Score is: 2763952.7433030996
# R2 Score is: 95.86970547617003
# Cross Validation Score: -2489.9776499874756
# R2 Score - Cross Validation Score is 2585.8473554636457

# %%
model=KNeighborsRegressor(n_neighbors=2, algorithm='kd_tree')
reg(model, X, Y)
# Out:
# RMSE Score is: 1518031.5415936552
# R2 Score is: 98.75410516476404
# Cross Validation Score: -1643.3320476428576
# R2 Score - Cross Validation Score is 1742.0861528076216

# %%
model=GradientBoostingRegressor(loss='quantile', n_estimators=200, max_depth=5)
reg(model, X, Y)
# Out:
# RMSE Score is: 4528557.344951726
# R2 Score is: 88.91234924523982
# Cross Validation Score: -263533.6175489397
# R2 Score - Cross Validation Score is 263622.52989818493

# %%
model=AdaBoostRegressor(n_estimators=300, learning_rate=1.05, random_state=42)
reg(model, X, Y)
# Out:
# RMSE Score is: 1782834.2465740405
# R2 Score is: 98.28153088807548
# Cross Validation Score: -1958.146073507043
# R2 Score - Cross Validation Score is 2056.4276043951186

# %%
model=ExtraTreesRegressor(n_estimators=200, max_features='sqrt', n_jobs=6)
reg(model, X, Y)
# Out:
# RMSE Score is: 1209649.613919167
# R2 Score is: 99.2088861695769
# Cross Validation Score: -637.8373215214976
# R2 Score - Cross Validation Score is 737.0462076910745

# %%
model=XGBRegressor()
reg(model, X, Y)
# Out:
# RMSE Score is: 1209392.094685713
# R2 Score is: 99.2092229701502
# Cross Validation Score: -397.57405561922377
# R2 Score - Cross Validation Score is 496.78327858937394

# %%
from sklearn.model_selection import GridSearchCV

# %%
fmod_param = {'n_estimators' : [200, 400, 600],
              'gamma' : [2.0, 3.0, 4.0],
              'max_depth' : [4, 6, 8],
              'n_jobs' : [-2, -1, 1]
             }

# %%
GSCV = GridSearchCV(XGBRegressor(), fmod_param, cv=5)

# %%
GSCV.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
# ...

# %%
GSCV.best_params_
# Out:
# {'gamma': 2.0, 'max_depth': 8, 'n_estimators': 200, 'n_jobs': -2}

# %%
Final_Model = XGBRegressor(gamma=2.0, max_depth=8, n_estimators=200, n_jobs=-2)
Classifier = Final_Model.fit(X_train, Y_train)
fmod_pred = Final_Model.predict(X_test)
fmod_r2 = r2_score(Y_test, fmod_pred)*100
print("R2 score for the Best Model is:", fmod_r2)
# Out:
# R2 score for the Best Model is: 99.20922342976532

# %%
import joblib
joblib.dump(Final_Model,'Home_Price_Prediction.pkl')
# Out:
# ['Home_Price_Prediction.pkl']

# %%
model=joblib.load("Home_Price_Prediction.pkl")
prediction=model.predict(X_test)
prediction
# Out:
# array([ 2000000.1,  3000000.2,  2800000. ,  4934210. , 32500000. ,
#        32500000. ,  2800000.2, 34318176. ,  2800000.2,  2999998.5,
#         1999999.9, 34999996. , 39999996. , 36999996. ,  3999999.8,
#         2800000.2,  3000000.2,  2999999.8,  4934210. , 31381576. ,
#        17812500. ,  2999999.8,  2999999.5,  2699999.2,  9999999. ,
#        25000000. ,  3000000.2, 26636362. ,  1999999.4, 29999998. ,
#         3999999.8,  4000001. ,  2800000. ,  2999999.8, 26636362. ,
#        34999996. , 26636362. ,  8372881.5,  3999999.8, 25000000. ,
#        10000002. ,  4000001. ,  2800000.2, 25000002. ,  3000000.2,
#        37405404. ,  2800000.5,  3000000.2,  2800000. , 39999996. ,
#         2999999.8,  3999999.2,  2800000.5,  2999999.8,  2745833.2,
#        25000002. ,  1999999.4,  2999999.8,  3000000.2,  3000000.2,
#        15000000. ,  3000000. ,  1999999.4,  2000000.1,  2999998.5,
#        30000002. ,  4934210. ,  2999999.8, 36999996. ,  1999999.9,
# ...

# %%
a=np.array(Y_test)
df1=pd.DataFrame()
df1['Predicted']=prediction
df1['Actual']=a
df1
# Out:
#         Predicted    Actual
# 0    2.000000e+06   2000000
# 1    3.000000e+06   3000000
# 2    2.800000e+06   2800000
# 3    4.934210e+06   4000000
# 4    3.250000e+07  32500000
# ..            ...       ...
# 749  4.000000e+07  40000000
# 750  3.000000e+06   3000000
# 751  2.800000e+06   2800000
# 752  3.278688e+06  15000000
# 753  2.500000e+07  25000000
#
# [754 rows x 2 columns]
